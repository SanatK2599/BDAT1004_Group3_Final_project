# %%
import requests
import time
import pandas as pd
#from pymongo import MongoClient
from flask import Flask, render_template

app = Flask(__name__)

#client = MongoClient("mongodb+srv://Ani:WeatherCan@cluster0.i5fm0.mongodb.net/WeatherDB?ssl=true&ssl_cert_reqs=CERT_NONE")
#db = client.get_database('WeatherDB')


r1 = requests.get("http://api.weatherapi.com/v1/current.json?key=e8ff6d7f35334f22a7c192339211708&q=New York&aqi=no")
r2 = requests.get("http://api.weatherapi.com/v1/current.json?key=e8ff6d7f35334f22a7c192339211708&q=Sydney&aqi=no")
r3 = requests.get("http://api.weatherapi.com/v1/current.json?key=e8ff6d7f35334f22a7c192339211708&q=Toronto&aqi=no")
r4 = requests.get("http://api.weatherapi.com/v1/current.json?key=e8ff6d7f35334f22a7c192339211708&q=Delhi&aqi=no")
r5 = requests.get("http://api.weatherapi.com/v1/current.json?key=e8ff6d7f35334f22a7c192339211708&q=London&aqi=no")
#while True:
if r1.status_code == 200:
    newyork = r1.json()
    print(newyork)
    
else:
    exit()
if r2.status_code == 200:
    sydney = r2.json()
    print(sydney)
    
else:
    exit()
if r3.status_code == 200:
    toronto = r3.json()
    print(toronto)
    
else:
    exit()
if r4.status_code == 200:
    delhi = r4.json()
    print(delhi)
    
else:
    exit()
if r5.status_code == 200:
    london = r5.json()
    print(london)
    
else:
    exit()


@app.route('/')
def home():
    newyork = r1.json()
    sydney = r2.json()
    toronto = r3.json()
    delhi = r4.json()
    london = r5.json()
    return render_template('pages/homePage.html', **locals())


# %% Toronto
@app.route('/toronto')
def toronto():
    toronto = r3.json()
    cityName = toronto['location']['name']
    temp_c = toronto['current']['temp_c']
    country= toronto['location']['country']
    localtime = toronto['location']['localtime']
    return render_template('pages/Toronto.html', **locals())

# %% Delhi
@app.route('/delhi')
def delhi():
    delhi = r4.json()
    cityName = delhi['location']['name']
    temp_c = delhi['current']['temp_c']
    country= delhi['location']['country']
    localtime = delhi['location']['localtime']
    return render_template('pages/Delhi.html', **locals())

# %% New York
@app.route('/newyork')
def newyork():
    newyork = r1.json()
    cityName = newyork['location']['name']
    temp_c = newyork['current']['temp_c']
    localtime = newyork['location']['localtime']
    return render_template('pages/New York.html', **locals())

# %% Sydney
@app.route('/sydney')
def sydney():
    sydney = r2.json()
    cityName = sydney['location']['name']
    temp_c = sydney['current']['temp_c']
    country= sydney['location']['country']
    localtime = sydney['location']['localtime']
    return render_template('pages/Sydney.html', **locals())

# %% London
@app.route('/london')
def london():
    london = r5.json()
    cityName = london['location']['name']
    temp_c = london['current']['temp_c']
    country= london['location']['country']
    localtime = london['location']['localtime']
    return render_template('pages/London.html', **locals())


#time.sleep(60)

if __name__ == "__main__":
    app.run()
# Out:
# {'location': {'name': 'New York', 'region': 'New York', 'country': 'United States of America', 'lat': 40.71, 'lon': -74.01, 'tz_id': 'America/New_York', 'localtime_epoch': 1639620054, 'localtime': '2021-12-15 21:00'}, 'current': {'last_updated_epoch': 1639619100, 'last_updated': '2021-12-15 20:45', 'temp_c': 10.0, 'temp_f': 50.0, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 5.6, 'wind_kph': 9.0, 'wind_degree': 50, 'wind_dir': 'NE', 'pressure_mb': 1029.0, 'pressure_in': 30.39, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 71, 'cloud': 100, 'feelslike_c': 8.0, 'feelslike_f': 46.5, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 1.0, 'gust_mph': 13.4, 'gust_kph': 21.6}}
# {'location': {'name': 'Sydney', 'region': 'New South Wales', 'country': 'Australia', 'lat': -33.88, 'lon': 151.22, 'tz_id': 'Australia/Sydney', 'localtime_epoch': 1639620054, 'localtime': '2021-12-16 13:00'}, 'current': {'last_updated_epoch': 1639619100, 'last_updated': '2021-12-16 12:45', 'temp_c': 23.0, 'temp_f': 73.4, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 16.1, 'wind_kph': 25.9, 'wind_degree': 130, 'wind_dir': 'SE', 'pressure_mb': 1013.0, 'pressure_in': 29.91, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 73, 'cloud': 75, 'feelslike_c': 25.0, 'feelslike_f': 77.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 5.0, 'gust_mph': 16.1, 'gust_kph': 25.9}}
# {'location': {'name': 'Toronto', 'region': 'Ontario', 'country': 'Canada', 'lat': 43.67, 'lon': -79.42, 'tz_id': 'America/Toronto', 'localtime_epoch': 1639620002, 'localtime': '2021-12-15 21:00'}, 'current': {'last_updated_epoch': 1639619100, 'last_updated': '2021-12-15 20:45', 'temp_c': 10.8, 'temp_f': 51.4, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 180, 'wind_dir': 'S', 'pressure_mb': 1017.0, 'pressure_in': 30.04, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 64, 'cloud': 0, 'feelslike_c': 8.4, 'feelslike_f': 47.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 17.9, 'gust_kph': 28.8}}
# {'location': {'name': 'Delhi', 'region': 'Delhi', 'country': 'India', 'lat': 28.67, 'lon': 77.22, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1639620002, 'localtime': '2021-12-16 7:30'}, 'current': {'last_updated_epoch': 1639619100, 'last_updated': '2021-12-16 07:15', 'temp_c': 12.0, 'temp_f': 53.6, 'is_day': 1, 'condition': {'text': 'Mist', 'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png', 'code': 1030}, 'wind_mph': 0.0, 'wind_kph': 0.0, 'wind_degree': 0, 'wind_dir': 'N', 'pressure_mb': 1019.0, 'pressure_in': 30.09, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 88, 'cloud': 0, 'feelslike_c': 11.7, 'feelslike_f': 53.0, 'vis_km': 1.2, 'vis_miles': 0.0, 'uv': 1.0, 'gust_mph': 7.2, 'gust_kph': 11.5}}
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1639620054, 'localtime': '2021-12-16 2:00'}, 'current': {'last_updated_epoch': 1639619100, 'last_updated': '2021-12-16 01:45', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 270, 'wind_dir': 'W', 'pressure_mb': 1035.0, 'pressure_in': 30.56, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 76, 'cloud': 100, 'feelslike_c': 10.4, 'feelslike_f': 50.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 7.6, 'gust_kph': 12.2}}
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Dec/2021 21:03:33] "GET /sydney HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2021 21:03:33] "GET /static/css/bootstrap-theme-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:33] "GET /static/css/bootstrap-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:35] "GET /london HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2021 21:03:35] "GET /static/css/bootstrap-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:35] "GET /static/css/bootstrap-theme-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2021 21:03:39] "GET /static/css/bootstrap-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:39] "GET /static/css/bootstrap-theme-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2021 21:03:40] "GET /static/css/bootstrap-theme-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:40] "GET /static/css/bootstrap-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:41] "GET /toronto HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2021 21:03:41] "GET /static/css/bootstrap-3.1.1.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Dec/2021 21:03:41] "GET /static/css/bootstrap-theme-3.1.1.min.css HTTP/1.1" 404 -
